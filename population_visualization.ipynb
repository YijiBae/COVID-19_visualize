# %%
import pandas as pd
from matplotlib import font_manager, rc
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_2019 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/data science/data/위경도변환_2019.csv")
df_2020 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/data science/data/위경도변환_2020.csv")

# %%
df_2019.head()
# Out:
#          id       x       y  ...   etl_ymd         위도          경도
# 0  52981549  319502  466493  ...  20190304  36.796232  127.095770
# 1  52981549  319502  466493  ...  20190315  36.796232  127.095770
# 2  52981549  319502  466493  ...  20190328  36.796232  127.095770
# 3  52981550  319502  466543  ...  20190310  36.796682  127.095764
# 4  52981550  319502  466543  ...  20190427  36.796682  127.095764
#
# [5 rows x 37 columns]

# %%
#쌍용_1동_2019 = df_2019[df_2019['admi_cd'] == 44133530]
#쌍용_1동_2020 = df_2020[df_2020['admi_cd'] == 44133530]
#acid_df_2019 = 쌍용_1동_2019
#acid_df_2020 = 쌍용_1동_2020

#쌍용_2동_2019 = df_2019[df_2019['admi_cd'] == 44133540]
#쌍용_2동_2020 = df_2020[df_2020['admi_cd'] == 44133540]
#acid_df_2019 = 쌍용_2동_2019
#acid_df_2020 = 쌍용_2동_2020

#쌍용_3동_2019 = df_2019[df_2019['admi_cd'] == 44133550]
#쌍용_3동_2020 = df_2020[df_2020['admi_cd'] == 44133550]
#acid_df_2019 = 쌍용_3동_2019
#acid_df_2020 = 쌍용_3동_2020


#불당동_2019 = df_2019[df_2019['admi_cd'] == 44133565]
#불당동_2020 = df_2020[df_2020['admi_cd'] == 44133565]
#acid_df_2019 = 불당동_2019
#acid_df_2020 = 불당동_2020


#부성_1동_2019 = df_2019[df_2019['admi_cd'] == 44133580]
#부성_1동_2020 = df_2020[df_2020['admi_cd'] == 44133580]
#acid_df_2019 = 부성_1동_2019
#acid_df_2020 = 부성_1동_2020

부성_2동_2019 = df_2019[df_2019['admi_cd'] == 44133590]
부성_2동_2020 = df_2020[df_2020['admi_cd'] == 44133590]
acid_df_2019 = 부성_2동_2019
acid_df_2020 = 부성_2동_2020

# %%
#필요없는 값 삭제하기 
sum_df_2019  = acid_df_2019.drop(['id', "x", "y",  "total", "timezn_cd", "admi_cd","etl_ymd"], axis = 1)
sum_df_2020 = acid_df_2020.drop(['id', "x", "y", "timezn_cd", "total", "admi_cd","etl_ymd"], axis = 1)


# 연령별로 남/녀 값 합치기
sum_df_2019 = sum_df_2019.sum(axis = 0)
sum_df_2020 = sum_df_2020.sum(axis = 0)

# %%
# 새로운 dataframe 생성
final_list = []
for i in range(0, 28):
    lists = []
    lists.append(sum_df_2019[i])
    lists.append(sum_df_2020[i])
    final_list.append(lists)
    
my_df = pd.DataFrame(data=final_list,columns=['2019', '2020'])
# 인덱스 재설정
my_df.index = ['남00','남10','남15', '남20', '남25','남30','남35','남40', '남45', '남50', '남55','남60','남65','남70', '여00','여10','여15','여20','여25','여30','여35','여40','여45','여50','여55','여60','여65','여70']

# %%
my_df
# Out:
#           2019       2020
# 남00    56109.0    18860.0
# 남10   303795.0   129275.0
# 남15   978605.0   593639.0
# 남20  2945620.0  2202172.0
# 남25  5361401.0  4852030.0
# 남30  4914325.0  4543291.0
# 남35  4475421.0  3858058.0
# 남40  3149269.0  2884941.0
# 남45  2932639.0  2555722.0
# 남50  2570819.0  2272087.0
# 남55  1929386.0  1895430.0
# 남60   875621.0   946122.0
# 남65   263045.0   337319.0
# 남70   190445.0   201469.0
# 여00    95750.0    37529.0
# 여10   246248.0   129816.0
# 여15   833262.0   501779.0
# 여20  2135577.0  1848246.0
# 여25  2914636.0  2581797.0
# 여30  2586049.0  2105070.0
# 여35  2030551.0  1596942.0
# 여40  1489528.0  1201613.0
# 여45  1700680.0  1345056.0
# 여50  1465207.0  1404158.0
# 여55  1059054.0   987464.0
# 여60   486806.0   469735.0
# 여65   181211.0   153979.0
# 여70   179472.0   156237.0

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

% config InlineBackend.figure_format = 'retina'

! apt -qq -y install fonts-nanum
# Out:
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 14 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 144865 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath)
plt.rc('font', family='NanumBarunGothic')
mpl.font_manager._rebuild()

color = ['#2764AC', '#77A0CF']
my_df.plot(kind="bar", figsize=(25, 10), fontsize=20, color = color)
plt.legend(prop={'size': 20})
plt.show()
#plt.savefig('result/부성 2동 나이대별 유동 인구 수.png')

# %%
my_df.sum()
# Out:
# 2019    26769779.0
# 2020    21103876.0
# dtype: float64

# %% [markdown]
# # 요일별 통계

# %%
df_2019_day = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/data science/data/2019_with_day.csv")
df_2020_day = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/data science/data/2020_with_day.csv")

# %%
#쌍용_1동_2019 = df_2019_day[df_2019['admi_cd'] == 44133530]
#쌍용_1동_2020 = df_2020_day[df_2020['admi_cd'] == 44133530]
#acid_df_2019 = 쌍용_1동_2019
#acid_df_2020 = 쌍용_1동_2020

#쌍용_2동_2019 = df_2019_day[df_2019['admi_cd'] == 44133540]
#쌍용_2동_2020 = df_2020_day[df_2020['admi_cd'] == 44133540]
#acid_df_2019 = 쌍용_2동_2019
#acid_df_2020 = 쌍용_2동_2020

#쌍용_3동_2019 = df_2019_day[df_2019['admi_cd'] == 44133550]
#쌍용_3동_2020 = df_2020_day[df_2020['admi_cd'] == 44133550]
#acid_df_2019 = 쌍용_3동_2019
#acid_df_2020 = 쌍용_3동_2020


#불당동_2019 = df_2019_day[df_2019['admi_cd'] == 44133565]
#불당동_2020 = df_2020_day[df_2020['admi_cd'] == 44133565]
#acid_df_2019 = 불당동_2019
#acid_df_2020 = 불당동_2020

#부성_1동_2019 = df_2019_day[df_2019['admi_cd'] == 44133580]
#부성_1동_2020 = df_2020_day[df_2020['admi_cd'] == 44133580]
#acid_df_2019 = 부성_1동_2019
#acid_df_2020 = 부성_1동_2020

부성_2동_2019 = df_2019_day[df_2019['admi_cd'] == 44133590]
부성_2동_2020 = df_2020_day[df_2020['admi_cd'] == 44133590]
acid_df_2019 = 부성_2동_2019
acid_df_2020 = 부성_2동_2020

# %%
df_2019_group = acid_df_2019.groupby('day')
df_2020_group = acid_df_2020.groupby('day')

sum_day_2019 = pd.DataFrame(df_2019_group.sum()['total'])
sum_day_2020 = pd.DataFrame(df_2020_group.sum()['total'])

# %%
# 2019년 2020년 요일 데이터 병합
sum_day = pd.merge(sum_day_2019, sum_day_2020, right_index = True, left_index= True)
# 행 이름 재설정
sum_day.columns = ['2019', '2020']
# 열 순서 재설정 (월화수목금토일)
sum_day = sum_day.reindex(index= ["월요일", "화요일", "수요일", "목요일", "금요일", "토요일", "일요일"])

# %%
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath)
plt.rc('font', family='NanumBarunGothic')
mpl.font_manager._rebuild()


color = ['#2764AC', '#77A0CF']
sum_day.plot(kind="bar", figsize=(25, 10), fontsize=20, color = color)
p#lt.ylim(0.0*(10000000), 9500000) 
plt.legend(prop={'size': 20})
plt.show()
#plt.savefig('/content/drive/MyDrive/Colab Notebooks/data science/result/부성2동 요일별 유동인구.png')

# %% [markdown]
# # 시간대별 분석

# %%
#쌍용_1동_2019 = df_2019_day[df_2019['admi_cd'] == 44133530]
#쌍용_1동_2020 = df_2020_day[df_2020['admi_cd'] == 44133530]
#acid_df_2019 = 쌍용_1동_2019
#acid_df_2020 = 쌍용_1동_2020

#쌍용_2동_2019 = df_2019_day[df_2019['admi_cd'] == 44133540]
#쌍용_2동_2020 = df_2020_day[df_2020['admi_cd'] == 44133540]
#acid_df_2019 = 쌍용_2동_2019
#acid_df_2020 = 쌍용_2동_2020

#쌍용_3동_2019 = df_2019_day[df_2019['admi_cd'] == 44133550]
#쌍용_3동_2020 = df_2020_day[df_2020['admi_cd'] == 44133550]
#acid_df_2019 = 쌍용_3동_2019
#acid_df_2020 = 쌍용_3동_2020


#불당동_2019 = df_2019[df_2019['admi_cd'] == 44133565]
#불당동_2020 = df_2020[df_2020['admi_cd'] == 44133565]
#acid_df_2019 = 불당동_2019
#acid_df_2020 = 불당동_2020

#부성_1동_2019 = df_2019[df_2019['admi_cd'] == 44133580]
#부성_1동_2020 = df_2020[df_2020['admi_cd'] == 44133580]
#acid_df_2019 = 부성_1동_2019
#acid_df_2020 = 부성_1동_2020

부성_2동_2019 = df_2019[df_2019['admi_cd'] == 44133590]
부성_2동_2020 = df_2020[df_2020['admi_cd'] == 44133590]
acid_df_2019 = 부성_2동_2019
acid_df_2020 = 부성_2동_2020

# %%
new_df_2019 = acid_df_2019[['total', 'admi_cd', 'timezn_cd']]
grouped = new_df_2019.groupby('timezn_cd')
sum_df_2019 = pd.DataFrame(grouped.sum()['total'])

# %%
new_df_2020 = acid_df_2020[['total', 'admi_cd', 'timezn_cd']]
grouped = new_df_2020.groupby('timezn_cd')
sum_df_2020 = pd.DataFrame(grouped.sum()['total'])

# %%
# 하루의 시간대 별이기 때문에 전체를 61로 나눈다. 
x_2019 = []
y_2019 = []
for i in range(24):
    x_2019.append(str(i)+"시")
    y_2019.append((sum_df_2019.iloc[i][0])/61)

# %%
# 하루의 시간대 별이기 때문에 전체를 61로 나눈다. 
x_2020 = []
y_2020 = []
for i in range(24):
    x_2020.append(str(i)+"시")
    y_2020.append((sum_df_2020.iloc[i][0])/61)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath)
plt.rc('font', family='NanumBarunGothic')
mpl.font_manager._rebuild()


plt.figure(figsize=(12, 3))
plt.plot(x_2020, y_2020, marker = "o", color = '#77A0CF')
plt.plot(x_2019, y_2019, marker = "o")
#plt.title("시간대별 유동인구 현황(명)")
plt.xlabel('시간')
plt.ylabel('평균 유동인구')
#plt.ylim(0.0*(1000000), 200000)
plt.legend(['2020', '2019'])
plt.savefig('/content/drive/MyDrive/Colab Notebooks/data science/result/부성 2동 시간대별 유동인구.png')
